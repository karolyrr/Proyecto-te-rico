# %%
from PIL import Image, ImageChops, ImageFilter
import sys
import matplotlib.pyplot as plt
import numpy as np
import random as rd

# %%
def distri_proba(q):

    #Obtención matrices de color

    img2 = plt.imread(q) #Lee la imágen en matrices de capas de colores

    c = np.shape(img2)

    g = list(img2[:,:,0]) #Capa verde
    r = list(img2[:,:,1]) #Capa roja
    b = list(img2[:,:,2]) #Capa azul

    #Divide una matriz de color en matrices 2x2

    lis = [] #Contiene números que conformarían matrices 2x2

    a = g

    for row in range(int(c[0])-1):

        if row%2 == 0: #Evita sobrelapamiento

            for column in range(int(c[1])-1):

                if column%2 == 0: #Evita sobrelapamiento

                    lista = [a[row][column],a[row][column+1],a[row+1][column],a[row+1][column+1]] #convierte en lista con info de matriz

                    lis.append(lista)

    #Cuenta con diccionarios

    conteos={'{}'.format([0,1,2,3]):0,'{}'.format([0,3,2,1]):0,'{}'.format([0,2,1,3]):0,'{}'.format([0,1,3,2]):0,
             '{}'.format([0,3,1,2]):0,'{}'.format([0,2,3,1]):0,'{}'.format([1,0,2,3]):0,'{}'.format([1,0,3,2]):0,
             '{}'.format([1,2,0,3]):0,'{}'.format([1,2,3,0]):0,'{}'.format([1,3,0,2]):0,'{}'.format([1,3,2,0]):0,
             '{}'.format([2,0,1,3]):0,'{}'.format([2,0,3,1]):0,'{}'.format([2,1,0,3]):0,'{}'.format([2,1,3,0]):0,
             '{}'.format([2,3,1,0]):0,'{}'.format([2,3,0,1]):0,'{}'.format([3,0,1,2]):0,'{}'.format([3,0,2,1]):0,
             '{}'.format([3,1,0,2]):0,'{}'.format([3,1,2,0]):0,'{}'.format([3,2,1,0]):0,'{}'.format([3,2,0,1]):0}

    for i in range(len(lis)):

        k = lis[i]

        pos = list(np.argsort(k)) #Organiza índices

        lis[i] = '{}'.format(pos)

        conteos[lis[i]] += 1/len(lis)

    conteo = list(conteos.values())
    
    probabilidad = conteo
    
    return probabilidad #Retorna lista con probabilidades

def comple_entro(proba_fotos):
    
    proba_u = 1/24
    
    entro_u = 0
    entro_f = 0
    entro_c = 0
    
    for i in range(24):
        
        entro_u += proba_u*-1*np.log(proba_u)
        if proba_fotos[i] != 0:
            
            entro_f += proba_fotos[i]*-1*np.log(proba_fotos[i])
        entro_c += (proba_fotos[i]+proba_u)/2*-1*np.log((proba_fotos[i]+proba_u)/2)
    
    entro_norm = entro_f/np.log(24)
    
    D = -1/2*( (25/24)*np.log(25) + np.log(24) - 2*np.log(48) )
    
    complejidad = (entro_c - 1/2 * entro_f - 1/2 * entro_u)*entro_norm/D
    
    return entro_norm, complejidad #retorna punto para plano entropía complejidad

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Adolescente = []

com_Adolescente = []

#--------------------------------------- Adolescente -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente.jpg')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-1-columna-1.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-1-columna-2.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-1-columna-3.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-1-columna-4.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-2-columna-1.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-2-columna-2.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-2-columna-3.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-2-columna-4.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-3-columna-1.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-3-columna-2.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-3-columna-3.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-3-columna-4.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-4-columna-1.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-4-columna-2.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-4-columna-3.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente/fila-4-columna-4.png')

c = comple_entro(d)

ent_Adolescente.append(c[0])

com_Adolescente.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Adolescente,com_Adolescente, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Adolescente[0],com_Adolescente[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Adolescente')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Adolescente.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 858.5, 878.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Africano = []

com_Africano = []

#--------------------------------------- Africano -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano.jpg')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-1-columna-1.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-1-columna-2.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-1-columna-3.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-1-columna-4.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-2-columna-1.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-2-columna-2.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-2-columna-3.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-2-columna-4.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-3-columna-1.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-3-columna-2.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-3-columna-3.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-3-columna-4.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-4-columna-1.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-4-columna-2.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-4-columna-3.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano/fila-4-columna-4.png')

c = comple_entro(d)

ent_Africano.append(c[0])

com_Africano.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Africano,com_Africano, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Africano[0],com_Africano[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Africano')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Africano.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 180.5, 194.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Albino = []

com_Albino = []

#--------------------------------------- Albino -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino.jpg')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-1-columna-1.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-1-columna-2.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-1-columna-3.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-1-columna-4.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-2-columna-1.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-2-columna-2.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-2-columna-3.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-2-columna-4.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-3-columna-1.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-3-columna-2.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-3-columna-3.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-3-columna-4.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-4-columna-1.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-4-columna-2.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-4-columna-3.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino/fila-4-columna-4.png')

c = comple_entro(d)

ent_Albino.append(c[0])

com_Albino.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Albino,com_Albino, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Albino[0],com_Albino[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Albino')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Albino.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 175.5, 181.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Anciano = []

com_Anciano = []

#--------------------------------------- Anciano -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano.jpg')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-1-columna-1.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-1-columna-2.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-1-columna-3.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-1-columna-4.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-2-columna-1.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-2-columna-2.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-2-columna-3.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-2-columna-4.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-3-columna-1.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-3-columna-2.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-3-columna-3.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-3-columna-4.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-4-columna-1.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-4-columna-2.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-4-columna-3.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano/fila-4-columna-4.png')

c = comple_entro(d)

ent_Anciano.append(c[0])

com_Anciano.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Anciano,com_Anciano, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Anciano[0],com_Anciano[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Anciano')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Anciano.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 304.5, 316.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Bebé = []

com_Bebé = []

#--------------------------------------- Bebé -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé.jpg')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-1-columna-1.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-1-columna-2.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-1-columna-3.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-1-columna-4.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-2-columna-1.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-2-columna-2.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-2-columna-3.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-2-columna-4.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-3-columna-1.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-3-columna-2.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-3-columna-3.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-3-columna-4.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-4-columna-1.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-4-columna-2.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-4-columna-3.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé/fila-4-columna-4.png')

c = comple_entro(d)

ent_Bebé.append(c[0])

com_Bebé.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Bebé,com_Bebé, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Bebé[0],com_Bebé[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Bebé')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Bebé.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 268.5, 299.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_China = []

com_China = []

#--------------------------------------- China -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China.jpg')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-1-columna-1.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-1-columna-2.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-1-columna-3.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-1-columna-4.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-2-columna-1.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-2-columna-2.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-2-columna-3.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-2-columna-4.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-3-columna-1.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-3-columna-2.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-3-columna-3.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-3-columna-4.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-4-columna-1.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-4-columna-2.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-4-columna-3.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China/fila-4-columna-4.png')

c = comple_entro(d)

ent_China.append(c[0])

com_China.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_China,com_China, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_China[0],com_China[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('China')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/China.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 155.5, 165.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Europeo = []

com_Europeo = []

#--------------------------------------- Europeo -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo.jpg')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-1-columna-1.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-1-columna-2.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-1-columna-3.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-1-columna-4.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-2-columna-1.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-2-columna-2.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-2-columna-3.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-2-columna-4.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-3-columna-1.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-3-columna-2.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-3-columna-3.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-3-columna-4.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-4-columna-1.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-4-columna-2.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-4-columna-3.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo/fila-4-columna-4.png')

c = comple_entro(d)

ent_Europeo.append(c[0])

com_Europeo.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Europeo,com_Europeo, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Europeo[0],com_Europeo[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Europeo')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Europeo.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 401.5, 413.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Indígena = []

com_Indígena = []

#--------------------------------------- Indígena -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena.jpg')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-1-columna-1.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-1-columna-2.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-1-columna-3.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-1-columna-4.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-2-columna-1.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-2-columna-2.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-2-columna-3.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-2-columna-4.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-3-columna-1.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-3-columna-2.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-3-columna-3.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-3-columna-4.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-4-columna-1.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-4-columna-2.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-4-columna-3.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena/fila-4-columna-4.png')

c = comple_entro(d)

ent_Indígena.append(c[0])

com_Indígena.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Indígena,com_Indígena, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Indígena[0],com_Indígena[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Indígena')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Indígena.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 196.5, 182.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Moreno = []

com_Moreno = []

#--------------------------------------- Moreno -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-1-columna-1.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-1-columna-2.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-1-columna-3.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-1-columna-4.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-2-columna-1.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-2-columna-2.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-2-columna-3.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-2-columna-4.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-3-columna-1.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-3-columna-2.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-3-columna-3.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-3-columna-4.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-4-columna-1.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-4-columna-2.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-4-columna-3.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno/fila-4-columna-4.png')

c = comple_entro(d)

ent_Moreno.append(c[0])

com_Moreno.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Moreno,com_Moreno, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Moreno[0],com_Moreno[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Moreno')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Moreno.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 637.5, 799.5, -0.5)

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_Rostro = []

com_Rostro = []

#--------------------------------------- Rostro -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro.jpg')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-1-columna-1.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-1-columna-2.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-1-columna-3.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-1-columna-4.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-2-columna-1.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-2-columna-2.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-2-columna-3.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-2-columna-4.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-3-columna-1.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-3-columna-2.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-3-columna-3.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-3-columna-4.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-4-columna-1.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-4-columna-2.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-4-columna-3.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Rostro/fila-4-columna-4.png')

c = comple_entro(d)

ent_Rostro.append(c[0])

com_Rostro.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Rostro,com_Rostro, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Rostro[0],com_Rostro[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Dibujo')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Rostros/Rostro.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 235.5, 235.5, -0.5)

# %%
#Todas las figuras

plt.figure(figsize=(12,5))

plt.scatter(ent_Rostro,com_Rostro, label='Sub-Dibujo', c = 'plum', s=10)
plt.scatter(ent_Rostro[0],com_Rostro[0], label='Dibujo', c = 'coral')

plt.scatter(ent_Moreno,com_Moreno, label='Sub-Moreno', c = 'plum', s=10)
plt.scatter(ent_Moreno[0],com_Moreno[0], label='Moreno', c = 'coral')

plt.scatter(ent_Indígena,com_Indígena, label='Sub-Indígena', c = 'plum', s=10)
plt.scatter(ent_Indígena[0],com_Indígena[0], label='Indígena', c = 'coral')

plt.scatter(ent_Europeo,com_Europeo, label='Sub-Europeo', c = 'plum', s=10)
plt.scatter(ent_Europeo[0],com_Europeo[0], label='Europeo', c = 'coral')

plt.scatter(ent_China,com_China, label='Sub-China', c = 'plum', s=10)
plt.scatter(ent_China[0],com_China[0], label='China', c = 'coral')

plt.scatter(ent_Bebé,com_Bebé, label='Sub-Bebé', c = 'plum', s=10)
plt.scatter(ent_Bebé[0],com_Bebé[0], label='Bebé', c = 'coral')

plt.scatter(ent_Anciano,com_Anciano, label='Sub-Anciano', c = 'plum', s=10)
plt.scatter(ent_Anciano[0],com_Anciano[0], label='Anciano', c = 'coral')

plt.scatter(ent_Albino,com_Albino, label='Sub-Albino', c = 'plum', s=10)
plt.scatter(ent_Albino[0],com_Albino[0], label='Albino', c = 'coral')

plt.scatter(ent_Africano,com_Africano, label='Sub-Africano', c = 'plum', s=10)
plt.scatter(ent_Africano[0],com_Africano[0], label='Africano', c = 'coral')

plt.scatter(ent_Adolescente,com_Adolescente, label='Sub-Adolescente', c = 'plum', s=10)
plt.scatter(ent_Adolescente[0],com_Adolescente[0], label='Adolescente', c = 'coral')

plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0.4,1)
plt.grid(linewidth=0.1)
#plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Complejidad normalizada')
plt.title('Dispersiones Rostros')
# Out:
# Text(0.5, 1.0, 'Dispersiones Rostros')
