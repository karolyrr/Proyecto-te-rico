# %%
from PIL import Image, ImageChops, ImageFilter
import sys
import matplotlib.pyplot as plt
import numpy as np
import random as rd

# %%
def distri_proba(q):

    #Obtención matrices de color

    img2 = plt.imread(q) #Lee la imágen en matrices de capas de colores

    c = np.shape(img2)

    g = list(img2[:,:,0]) #Capa verde
    r = list(img2[:,:,1]) #Capa roja
    b = list(img2[:,:,2]) #Capa azul

    #Divide una matriz de color en matrices 2x2

    lis = [] #Contiene números que conformarían matrices 2x2

    a = g

    for row in range(int(c[0])-1):

        if row%2 == 0: #Evita sobrelapamiento

            for column in range(int(c[1])-1):

                if column%2 == 0: #Evita sobrelapamiento

                    lista = [a[row][column],a[row][column+1],a[row+1][column],a[row+1][column+1]] #convierte en lista con info de matriz

                    lis.append(lista)

    #Cuenta con diccionarios

    conteos={'{}'.format([0,1,2,3]):0,'{}'.format([0,3,2,1]):0,'{}'.format([0,2,1,3]):0,'{}'.format([0,1,3,2]):0,
             '{}'.format([0,3,1,2]):0,'{}'.format([0,2,3,1]):0,'{}'.format([1,0,2,3]):0,'{}'.format([1,0,3,2]):0,
             '{}'.format([1,2,0,3]):0,'{}'.format([1,2,3,0]):0,'{}'.format([1,3,0,2]):0,'{}'.format([1,3,2,0]):0,
             '{}'.format([2,0,1,3]):0,'{}'.format([2,0,3,1]):0,'{}'.format([2,1,0,3]):0,'{}'.format([2,1,3,0]):0,
             '{}'.format([2,3,1,0]):0,'{}'.format([2,3,0,1]):0,'{}'.format([3,0,1,2]):0,'{}'.format([3,0,2,1]):0,
             '{}'.format([3,1,0,2]):0,'{}'.format([3,1,2,0]):0,'{}'.format([3,2,1,0]):0,'{}'.format([3,2,0,1]):0}

    for i in range(len(lis)):

        k = lis[i]

        pos = list(np.argsort(k)) #Organiza índices

        lis[i] = '{}'.format(pos)

        conteos[lis[i]] += 1/len(lis)

    conteo = list(conteos.values())
    
    probabilidad = conteo
    
    return probabilidad #Retorna lista con probabilidades

def comple_entro(proba_fotos):
    
    proba_u = 1/24
    
    entro_u = 0
    entro_f = 0
    entro_c = 0
    
    for i in range(24):
        
        entro_u += proba_u*-1*np.log(proba_u)
        if proba_fotos[i] != 0:
            
            entro_f += proba_fotos[i]*-1*np.log(proba_fotos[i])
        entro_c += (proba_fotos[i]+proba_u)/2*-1*np.log((proba_fotos[i]+proba_u)/2)
    
    entro_norm = entro_f/np.log(24)
    
    D = -1/2*( (25/24)*np.log(25) + np.log(24) - 2*np.log(48) )
    
    complejidad = (entro_c - 1/2 * entro_f - 1/2 * entro_u)*entro_norm/D
    
    return entro_norm, complejidad #retorna punto para plano entropía complejidad

# %%
# otros --------------------------------------------------------------------------------------------------

ent_o = []

com_o = []

#-------------------descarga-----------------------------------------------------------------

d = distri_proba('Imágenes/Otros/descarga.jpg')

c = comple_entro(d)

ent_o.append(c[0])

com_o.append(c[1])

#-------------------descarga2-----------------------------------------------------------------

d = distri_proba('Imágenes/Otros/descarga2.jpg')

c = comple_entro(d)

ent_o.append(c[0])

com_o.append(c[1])

#-------------------histograma-----------------------------------------------------------------

d = distri_proba('Imágenes/Otros/Histograma.png')

c = comple_entro(d)

ent_o.append(c[0])

com_o.append(c[1])

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_a = []

com_a = []

#-------------------1-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

#-------------------2-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

#-------------------4-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

#-------------------5-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

#-------------------6-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

#-------------------7-----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7.jpg')

c = comple_entro(d)

ent_a.append(c[0])

com_a.append(c[1])

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_m = []

com_m = []

#-------------------micro 3-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 4-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4.jpeg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 5-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 6-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 7-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7.jpeg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 8-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 9-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------micro 10-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10.jpg')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

#-------------------microscopía-----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía.PNG')

c = comple_entro(d)

ent_m.append(c[0])

com_m.append(c[1])

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_r = []

com_r = []

#-------------------Adolescente-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Adolescente.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Africano-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Africano.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Albino-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Albino.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Anciano-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Anciano.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Bebé-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Bebé.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------China-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/China.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Europeo-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Europeo.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Indígena-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Indígena.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Moreno-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/Moreno.png')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

#-------------------Rostro-----------------------------------------------------------------

d = distri_proba('Imágenes/Rostros/rostro.jpg')

c = comple_entro(d)

ent_r.append(c[0])

com_r.append(c[1])

# %%
# Rostros --------------------------------------------------------------------------------------------------

ent_art = []

com_art = []

#-------------------Art1-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art2-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art3-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art4-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art5-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art6-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art7-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art8-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art9-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

#-------------------Art10-----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10.jpg')

c = comple_entro(d)

ent_art.append(c[0])

com_art.append(c[1])

# %%
#Todas las gráficas juntas

plt.scatter(ent_o,com_o, label='Otros', c = 'skyblue')
plt.scatter(ent_a,com_a, label='Astronomía', c = 'plum')
plt.scatter(ent_m,com_m, label='Microscopía', c = 'peru')
plt.scatter(ent_r,com_r, label='Rostros', c = 'silver')
plt.scatter(ent_art,com_art, label='Obras de arte', c = 'gold')
plt.xlabel('Entropía normalizada')
plt.ylim(0,1)
plt.ylabel('Complejidad normalizada')
plt.legend()
plt.grid(linewidth=0.1)
plt.title('Varias categorías')
# Out:
# Text(0.5, 1.0, 'Varias categorías')

# %%
#Astronomía

plt.scatter(ent_a,com_a, label='Astronomía', c = 'plum')
plt.xlabel('Entropía normalizada')
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía')
# Out:
# Text(0.5, 1.0, 'Astronomía')

# %%
# Rostros 

plt.scatter(ent_r,com_r, label='Rostros', c = 'silver')
plt.xlabel('Entropía normalizada')
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Rostros')
# Out:
# Text(0.5, 1.0, 'Rostros')

# %%
# Microscopía

plt.scatter(ent_m,com_m, label='Microscopía', c = 'peru')
plt.xlabel('Entropía normalizada')
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Microscopía')
# Out:
# Text(0.5, 1.0, 'Microscopía')

# %%
# Obras de arte

plt.scatter(ent_art,com_art, label='Obras de arte', c = 'goldenrod')
plt.xlabel('Entropía normalizada')
plt.ylim(0,1)
plt.xlim(0,1)
plt.ylabel('Complejidad normalizada')
plt.legend()
plt.grid(linewidth=0.1)
plt.title('Varias categorías')
# Out:
# Text(0.5, 1.0, 'Varias categorías')
