# %%
from PIL import Image, ImageChops, ImageFilter
import sys
import matplotlib.pyplot as plt
import numpy as np
import random as rd

# %%
def distri_proba(q):

    #Obtención matrices de color

    img2 = plt.imread(q) #Lee la imágen en matrices de capas de colores

    c = np.shape(img2)

    g = list(img2[:,:,0]) #Capa verde
    r = list(img2[:,:,1]) #Capa roja
    b = list(img2[:,:,2]) #Capa azul

    #Divide una matriz de color en matrices 2x2

    lis = [] #Contiene números que conformarían matrices 2x2

    a = g

    for row in range(int(c[0])-1):

        if row%2 == 0: #Evita sobrelapamiento

            for column in range(int(c[1])-1):

                if column%2 == 0: #Evita sobrelapamiento

                    lista = [a[row][column],a[row][column+1],a[row+1][column],a[row+1][column+1]] #convierte en lista con info de matriz

                    lis.append(lista)

    #Cuenta con diccionarios

    conteos={'{}'.format([0,1,2,3]):0,'{}'.format([0,3,2,1]):0,'{}'.format([0,2,1,3]):0,'{}'.format([0,1,3,2]):0,
             '{}'.format([0,3,1,2]):0,'{}'.format([0,2,3,1]):0,'{}'.format([1,0,2,3]):0,'{}'.format([1,0,3,2]):0,
             '{}'.format([1,2,0,3]):0,'{}'.format([1,2,3,0]):0,'{}'.format([1,3,0,2]):0,'{}'.format([1,3,2,0]):0,
             '{}'.format([2,0,1,3]):0,'{}'.format([2,0,3,1]):0,'{}'.format([2,1,0,3]):0,'{}'.format([2,1,3,0]):0,
             '{}'.format([2,3,1,0]):0,'{}'.format([2,3,0,1]):0,'{}'.format([3,0,1,2]):0,'{}'.format([3,0,2,1]):0,
             '{}'.format([3,1,0,2]):0,'{}'.format([3,1,2,0]):0,'{}'.format([3,2,1,0]):0,'{}'.format([3,2,0,1]):0}

    for i in range(len(lis)):

        k = lis[i]

        pos = list(np.argsort(k)) #Organiza índices

        lis[i] = '{}'.format(pos)

        conteos[lis[i]] += 1/len(lis)

    conteo = list(conteos.values())
    
    probabilidad = conteo
    
    return probabilidad #Retorna lista con probabilidades

def comple_entro(proba_fotos):
    
    proba_u = 1/24
    
    entro_u = 0
    entro_f = 0
    entro_c = 0
    
    for i in range(24):
        
        entro_u += proba_u*-1*np.log(proba_u)
        if proba_fotos[i] != 0:
            
            entro_f += proba_fotos[i]*-1*np.log(proba_fotos[i])
        entro_c += (proba_fotos[i]+proba_u)/2*-1*np.log((proba_fotos[i]+proba_u)/2)
    
    entro_norm = entro_f/np.log(24)
    
    D = -1/2*( (25/24)*np.log(25) + np.log(24) - 2*np.log(48) )
    
    complejidad = (entro_c - 1/2 * entro_f - 1/2 * entro_u)*entro_norm/D
    
    return entro_norm, complejidad #retorna punto para plano entropía complejidad

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_1 = []

com_1 = []

#--------------------------------------- 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1.jpg')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-1-columna-1.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-1-columna-2.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-1-columna-3.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-1-columna-4.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-2-columna-1.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-2-columna-2.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-2-columna-3.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-2-columna-4.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-3-columna-1.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-3-columna-2.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-3-columna-3.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-3-columna-4.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-4-columna-1.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-4-columna-2.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-4-columna-3.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/1/fila-4-columna-4.png')

c = comple_entro(d)

ent_1.append(c[0])

com_1.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_1,com_1, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_1[0],com_1[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 1')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/1.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 270.5, 185.5, -0.5)

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_2 = []

com_2 = []

#--------------------------------------- 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2.jpg')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-1-columna-1.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-1-columna-2.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-1-columna-3.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-1-columna-4.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-2-columna-1.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-2-columna-2.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-2-columna-3.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-2-columna-4.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-3-columna-1.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-3-columna-2.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-3-columna-3.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-3-columna-4.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-4-columna-1.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-4-columna-2.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-4-columna-3.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/2/fila-4-columna-4.png')

c = comple_entro(d)

ent_2.append(c[0])

com_2.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_2,com_2, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_2[0],com_2[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 2')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/2.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 931.5, -0.5)

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_3 = []

com_3 = []

#--------------------------------------- 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4.jpg')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-1-columna-1.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-1-columna-2.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-1-columna-3.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-1-columna-4.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-2-columna-1.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-2-columna-2.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-2-columna-3.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-2-columna-4.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-3-columna-1.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-3-columna-2.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-3-columna-3.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-3-columna-4.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-4-columna-1.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-4-columna-2.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-4-columna-3.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/4/fila-4-columna-4.png')

c = comple_entro(d)

ent_3.append(c[0])

com_3.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_3,com_3, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_3[0],com_3[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 4')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/4.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 9128.5, 3773.5, -0.5)

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_4 = []

com_4 = []

#--------------------------------------- 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5.jpg')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-1-columna-1.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-1-columna-2.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-1-columna-3.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-1-columna-4.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-2-columna-1.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-2-columna-2.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-2-columna-3.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-2-columna-4.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-3-columna-1.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-3-columna-2.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-3-columna-3.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-3-columna-4.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-4-columna-1.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-4-columna-2.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-4-columna-3.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/5/fila-4-columna-4.png')

c = comple_entro(d)

ent_4.append(c[0])

com_4.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_4,com_4, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_4[0],com_4[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 5')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/5.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_5 = []

com_5 = []

#--------------------------------------- 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6.jpg')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-1-columna-1.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-1-columna-2.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-1-columna-3.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-1-columna-4.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-2-columna-1.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-2-columna-2.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-2-columna-3.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-2-columna-4.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-3-columna-1.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-3-columna-2.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-3-columna-3.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-3-columna-4.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-4-columna-1.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-4-columna-2.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-4-columna-3.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/6/fila-4-columna-4.png')

c = comple_entro(d)

ent_5.append(c[0])

com_5.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_5,com_5, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_5[0],com_5[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 6')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/6.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 1279.5, -0.5)

# %%
# Astronomía --------------------------------------------------------------------------------------------------

ent_6 = []

com_6 = []

#--------------------------------------- 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7.jpg')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-1-columna-1.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-1-columna-2.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-1-columna-3.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-1-columna-4.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-2-columna-1.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-2-columna-2.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-2-columna-3.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-2-columna-4.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-3-columna-1.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-3-columna-2.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-3-columna-3.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-3-columna-4.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-4-columna-1.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-4-columna-2.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-4-columna-3.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Astronomía/7/fila-4-columna-4.png')

c = comple_entro(d)

ent_6.append(c[0])

com_6.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_6,com_6, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_6[0],com_6[0], label='Figura completa', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Astronomía 7')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Astronomía/7.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %%
#Todas las figuras de astronomía

plt.figure(figsize=(12,5))

plt.scatter(ent_1,com_1, label='Sub-figuras 1', c = 'skyblue', s=12)
plt.scatter(ent_1[0],com_1[0], label='Figura completa 1', c = 'darkcyan')

plt.scatter(ent_2,com_2, label='Sub-figuras 2', c = 'pink', s=12)
plt.scatter(ent_2[0],com_2[0], label='Figura completa 2', c = 'palevioletred')

plt.scatter(ent_3,com_3, label='Sub-figuras 4', c = 'palegreen', s=12)
plt.scatter(ent_3[0],com_3[0], label='Figura completa 4', c = 'darkseagreen')

plt.scatter(ent_4,com_4, label='Sub-figuras 5', c = 'lightcoral', s=12)
plt.scatter(ent_4[0],com_4[0], label='Figura completa 5', c = 'firebrick')

plt.scatter(ent_5,com_5, label='Sub-figuras 6', c = 'burlywood', s=12)
plt.scatter(ent_5[0],com_5[0], label='Figura completa 6', c = 'goldenrod')

plt.scatter(ent_6,com_6, label='Sub-figuras 7', c = 'silver', s=12)
plt.scatter(ent_6[0],com_6[0], label='Figura completa 7', c = 'dimgray')

plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0.4,1)
plt.grid(linewidth=0.1)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Complejidad normalizada')
plt.title('Dispersiones astronomía')
# Out:
# Text(0.5, 1.0, 'Dispersiones astronomía')
