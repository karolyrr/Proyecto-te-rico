# %%
from PIL import Image, ImageChops, ImageFilter
import sys
import matplotlib.pyplot as plt
import numpy as np
import random as rd

def distri_proba(q):

    #Obtención matrices de color

    img2 = plt.imread(q) #Lee la imágen en matrices de capas de colores

    c = np.shape(img2)

    g = list(img2[:,:,0]) #Capa verde
    r = list(img2[:,:,1]) #Capa roja
    b = list(img2[:,:,2]) #Capa azul

    #Divide una matriz de color en matrices 2x2

    lis = [] #Contiene números que conformarían matrices 2x2

    a = g

    for row in range(int(c[0])-1):

        if row%2 == 0: #Evita sobrelapamiento

            for column in range(int(c[1])-1):

                if column%2 == 0: #Evita sobrelapamiento

                    lista = [a[row][column],a[row][column+1],a[row+1][column],a[row+1][column+1]] #convierte en lista con info de matriz

                    lis.append(lista)

    #Cuenta con diccionarios

    conteos={'{}'.format([0,1,2,3]):0,'{}'.format([0,3,2,1]):0,'{}'.format([0,2,1,3]):0,'{}'.format([0,1,3,2]):0,
             '{}'.format([0,3,1,2]):0,'{}'.format([0,2,3,1]):0,'{}'.format([1,0,2,3]):0,'{}'.format([1,0,3,2]):0,
             '{}'.format([1,2,0,3]):0,'{}'.format([1,2,3,0]):0,'{}'.format([1,3,0,2]):0,'{}'.format([1,3,2,0]):0,
             '{}'.format([2,0,1,3]):0,'{}'.format([2,0,3,1]):0,'{}'.format([2,1,0,3]):0,'{}'.format([2,1,3,0]):0,
             '{}'.format([2,3,1,0]):0,'{}'.format([2,3,0,1]):0,'{}'.format([3,0,1,2]):0,'{}'.format([3,0,2,1]):0,
             '{}'.format([3,1,0,2]):0,'{}'.format([3,1,2,0]):0,'{}'.format([3,2,1,0]):0,'{}'.format([3,2,0,1]):0}

    for i in range(len(lis)):

        k = lis[i]

        pos = list(np.argsort(k)) #Organiza índices

        lis[i] = '{}'.format(pos)

        conteos[lis[i]] += 1/len(lis)

    conteo = list(conteos.values())
    
    probabilidad = conteo
    
    return probabilidad #Retorna lista con probabilidades

def comple_entro(proba_fotos):
    
    proba_u = 1/24
    
    entro_u = 0
    entro_f = 0
    entro_c = 0
    
    for i in range(24):
        
        entro_u += proba_u*-1*np.log(proba_u)
        if proba_fotos[i] != 0:
            
            entro_f += proba_fotos[i]*-1*np.log(proba_fotos[i])
        entro_c += (proba_fotos[i]+proba_u)/2*-1*np.log((proba_fotos[i]+proba_u)/2)
    
    entro_norm = entro_f/np.log(24)
    
    D = -1/2*( (25/24)*np.log(25) + np.log(24) - 2*np.log(48) )
    
    complejidad = (entro_c - 1/2 * entro_f - 1/2 * entro_u)*entro_norm/D
    
    return entro_norm, complejidad #retorna punto para plano entropía complejidad

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art1 = []

com_Art1 = []

#--------------------------------------- Art1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1.jpg')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art1/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art1.append(c[0])

com_Art1.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art1,com_Art1, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art1[0],com_Art1[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art1')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art1.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 144.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art2 = []

com_Art2 = []

#--------------------------------------- Art2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2.jpg')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art2/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art2.append(c[0])

com_Art2.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art2,com_Art2, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art2[0],com_Art2[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art2')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art2.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 213.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art3 = []

com_Art3 = []

#--------------------------------------- Art3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3.jpg')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art3/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art3.append(c[0])

com_Art3.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art3,com_Art3, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art3[0],com_Art3[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art3')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art3.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 182.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art4 = []

com_Art4 = []

#--------------------------------------- Art4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4.jpg')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art4/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art4.append(c[0])

com_Art4.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art4,com_Art4, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art4[0],com_Art4[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art4')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art4.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 271.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art5 = []

com_Art5 = []

#--------------------------------------- Art5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5.jpg')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art5/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art5.append(c[0])

com_Art5.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art5,com_Art5, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art5[0],com_Art5[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art5')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art5.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 338.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art6 = []

com_Art6 = []

#--------------------------------------- Art6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6.jpg')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art6/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art6.append(c[0])

com_Art6.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art6,com_Art6, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art6[0],com_Art6[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art6')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art6.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 295.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art7 = []

com_Art7 = []

#--------------------------------------- Art7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7.jpg')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art7/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art7.append(c[0])

com_Art7.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art7,com_Art7, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art7[0],com_Art7[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art7')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art7.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 195.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art8 = []

com_Art8 = []

#--------------------------------------- Art8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8.jpg')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art8/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art8.append(c[0])

com_Art8.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art8,com_Art8, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art8[0],com_Art8[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art8')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art8.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 152.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art9 = []

com_Art9 = []

#--------------------------------------- Art9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9.jpg')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art9/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art9.append(c[0])

com_Art9.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art9,com_Art9, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art9[0],com_Art9[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art9')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art9.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 272.5, -0.5)

# %%
# Obras de arte --------------------------------------------------------------------------------------------------

ent_Art10 = []

com_Art10 = []

#--------------------------------------- Art10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10.jpg')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-1-columna-1.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-1-columna-2.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-1-columna-3.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-1-columna-4.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-2-columna-1.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-2-columna-2.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-2-columna-3.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-2-columna-4.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-3-columna-1.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-3-columna-2.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-3-columna-3.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-3-columna-4.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-4-columna-1.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-4-columna-2.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-4-columna-3.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Obras de arte/Art10/fila-4-columna-4.png')

c = comple_entro(d)

ent_Art10.append(c[0])

com_Art10.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_Art10,com_Art10, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_Art10[0],com_Art10[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('Art10')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Obras de arte/Art10.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 209.5, 257.5, -0.5)

# %%
#Todas las figuras

plt.figure(figsize=(12,5))

plt.scatter(ent_Art1,com_Art1, label='Sub-Art1', c = 'plum', s=10)
plt.scatter(ent_Art1[0],com_Art1[0], label='Art1', c = 'coral')

plt.scatter(ent_Art2,com_Art2, label='Sub-Art2', c = 'plum', s=10)
plt.scatter(ent_Art2[0],com_Art2[0], label='Art2', c = 'coral')

plt.scatter(ent_Art10,com_Art10, label='Sub-Art10', c = 'plum', s=10)
plt.scatter(ent_Art10[0],com_Art10[0], label='Art10', c = 'coral')

plt.scatter(ent_Art9,com_Art9, label='Sub-Art9', c = 'plum', s=10)
plt.scatter(ent_Art9[0],com_Art9[0], label='Art9', c = 'coral')

plt.scatter(ent_Art8,com_Art8, label='Sub-Art8', c = 'plum', s=10)
plt.scatter(ent_Art8[0],com_Art8[0], label='Art8', c = 'coral')

plt.scatter(ent_Art7,com_Art7, label='Sub-Art7', c = 'plum', s=10)
plt.scatter(ent_Art7[0],com_Art7[0], label='Art7', c = 'coral')

plt.scatter(ent_Art6,com_Art6, label='Sub-Art6', c = 'plum', s=10)
plt.scatter(ent_Art6[0],com_Art6[0], label='Art6', c = 'coral')

plt.scatter(ent_Art5,com_Art5, label='Sub-Art5', c = 'plum', s=10)
plt.scatter(ent_Art5[0],com_Art5[0], label='Art5', c = 'coral')

plt.scatter(ent_Art4,com_Art4, label='Sub-Art4', c = 'plum', s=10)
plt.scatter(ent_Art4[0],com_Art4[0], label='Art4', c = 'coral')

plt.scatter(ent_Art3,com_Art3, label='Sub-Art3', c = 'plum', s=10)
plt.scatter(ent_Art3[0],com_Art3[0], label='Art3', c = 'coral')

plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0.4,1)
plt.grid(linewidth=0.1)
#plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Complejidad normalizada')
plt.title('Dispersiones Arte')
# Out:
# Text(0.5, 1.0, 'Dispersiones Arte')
