# %%
from PIL import Image, ImageChops, ImageFilter
import sys
import matplotlib.pyplot as plt
import numpy as np
import random as rd

def distri_proba(q):

    #Obtención matrices de color

    img2 = plt.imread(q) #Lee la imágen en matrices de capas de colores

    c = np.shape(img2)

    g = list(img2[:,:,0]) #Capa verde
    r = list(img2[:,:,1]) #Capa roja
    b = list(img2[:,:,2]) #Capa azul

    #Divide una matriz de color en matrices 2x2

    lis = [] #Contiene números que conformarían matrices 2x2

    a = g

    for row in range(int(c[0])-1):

        if row%2 == 0: #Evita sobrelapamiento

            for column in range(int(c[1])-1):

                if column%2 == 0: #Evita sobrelapamiento

                    lista = [a[row][column],a[row][column+1],a[row+1][column],a[row+1][column+1]] #convierte en lista con info de matriz

                    lis.append(lista)

    #Cuenta con diccionarios

    conteos={'{}'.format([0,1,2,3]):0,'{}'.format([0,3,2,1]):0,'{}'.format([0,2,1,3]):0,'{}'.format([0,1,3,2]):0,
             '{}'.format([0,3,1,2]):0,'{}'.format([0,2,3,1]):0,'{}'.format([1,0,2,3]):0,'{}'.format([1,0,3,2]):0,
             '{}'.format([1,2,0,3]):0,'{}'.format([1,2,3,0]):0,'{}'.format([1,3,0,2]):0,'{}'.format([1,3,2,0]):0,
             '{}'.format([2,0,1,3]):0,'{}'.format([2,0,3,1]):0,'{}'.format([2,1,0,3]):0,'{}'.format([2,1,3,0]):0,
             '{}'.format([2,3,1,0]):0,'{}'.format([2,3,0,1]):0,'{}'.format([3,0,1,2]):0,'{}'.format([3,0,2,1]):0,
             '{}'.format([3,1,0,2]):0,'{}'.format([3,1,2,0]):0,'{}'.format([3,2,1,0]):0,'{}'.format([3,2,0,1]):0}

    for i in range(len(lis)):

        k = lis[i]

        pos = list(np.argsort(k)) #Organiza índices

        lis[i] = '{}'.format(pos)

        conteos[lis[i]] += 1/len(lis)

    conteo = list(conteos.values())
    
    probabilidad = conteo
    
    return probabilidad #Retorna lista con probabilidades

def comple_entro(proba_fotos):
    
    proba_u = 1/24
    
    entro_u = 0
    entro_f = 0
    entro_c = 0
    
    for i in range(24):
        
        entro_u += proba_u*-1*np.log(proba_u)
        if proba_fotos[i] != 0:
            
            entro_f += proba_fotos[i]*-1*np.log(proba_fotos[i])
        entro_c += (proba_fotos[i]+proba_u)/2*-1*np.log((proba_fotos[i]+proba_u)/2)
    
    entro_norm = entro_f/np.log(24)
    
    D = -1/2*( (25/24)*np.log(25) + np.log(24) - 2*np.log(48) )
    
    complejidad = (entro_c - 1/2 * entro_f - 1/2 * entro_u)*entro_norm/D
    
    return entro_norm, complejidad #retorna punto para plano entropía complejidad

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro3 = []

com_micro3 = []

#--------------------------------------- micro3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3.jpg')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro3/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro3.append(c[0])

com_micro3.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro3,com_micro3, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro3[0],com_micro3[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro3')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro3.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 349.5, 279.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro4 = []

com_micro4 = []

#--------------------------------------- micro4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4.jpeg')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro4/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro4.append(c[0])

com_micro4.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro4,com_micro4, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro4[0],com_micro4[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro4')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro4.jpeg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 799.5, 426.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro5 = []

com_micro5 = []

#--------------------------------------- micro5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5.jpg')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro5/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro5.append(c[0])

com_micro5.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro5,com_micro5, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro5[0],com_micro5[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro5')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro5.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 499.5, 325.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro6 = []

com_micro6 = []

#--------------------------------------- micro6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6.jpg')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro6/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro6.append(c[0])

com_micro6.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro6,com_micro6, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro6[0],com_micro6[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro6')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro6.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 672.5, 455.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro7 = []

com_micro7 = []

#--------------------------------------- micro7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7.jpeg')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro7/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro7.append(c[0])

com_micro7.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro7,com_micro7, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro7[0],com_micro7[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro7')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro7.jpeg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 653.5, 490.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro8 = []

com_micro8 = []

#--------------------------------------- micro8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8.jpg')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro8/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro8.append(c[0])

com_micro8.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro8,com_micro8, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro8[0],com_micro8[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro8')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro8.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 799.5, 629.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro9 = []

com_micro9 = []

#--------------------------------------- micro9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9.jpg')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro9/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro9.append(c[0])

com_micro9.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro9,com_micro9, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro9[0],com_micro9[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro9')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro9.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 639.5, 374.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_micro10 = []

com_micro10 = []

#--------------------------------------- micro10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10.jpg')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-1-columna-1.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-1-columna-2.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-1-columna-3.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-1-columna-4.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-2-columna-1.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-2-columna-2.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-2-columna-3.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-2-columna-4.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-3-columna-1.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-3-columna-2.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-3-columna-3.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-3-columna-4.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-4-columna-1.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-4-columna-2.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-4-columna-3.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/micro10/fila-4-columna-4.png')

c = comple_entro(d)

ent_micro10.append(c[0])

com_micro10.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_micro10,com_micro10, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_micro10[0],com_micro10[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('micro10')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/micro10.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 346.5, 279.5, -0.5)

# %%
# Microscopía --------------------------------------------------------------------------------------------------

ent_microscopía = []

com_microscopía = []

#--------------------------------------- microscopía -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía.PNG')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 1 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-1-columna-1.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 2 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-1-columna-2.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 3 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-1-columna-3.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 4 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-1-columna-4.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 5 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-2-columna-1.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 6 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-2-columna-2.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 7 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-2-columna-3.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 8 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-2-columna-4.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 9 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-3-columna-1.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 10 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-3-columna-2.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 11 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-3-columna-3.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 12 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-3-columna-4.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 13 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-4-columna-1.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 14 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-4-columna-2.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 15 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-4-columna-3.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

#--------------------------------------- sub 16 -----------------------------------------------------------------

d = distri_proba('Imágenes/Microscopía/microscopía/fila-4-columna-4.png')

c = comple_entro(d)

ent_microscopía.append(c[0])

com_microscopía.append(c[1])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(ent_microscopía,com_microscopía, label='Sub-figuras', c = 'plum', s=10)
plt.scatter(ent_microscopía[0],com_microscopía[0], label='Figura principal', c = 'coral')
plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0,1)
plt.legend()
plt.grid(linewidth=0.1)
plt.ylabel('Complejidad normalizada')
plt.title('microscopía')
plt.subplot(1,2,2)
img = plt.imread('Imágenes/Microscopía/microscopía.PNG')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 847.5, 409.5, -0.5)

# %%
#Todas las figuras

plt.figure(figsize=(12,5))

plt.scatter(ent_microscopía,com_microscopía, label='Sub-microscopía', c = 'plum', s=10)
plt.scatter(ent_microscopía[0],com_microscopía[0], label='microscopía', c = 'coral')

plt.scatter(ent_micro10,com_micro10, label='Sub-micro10', c = 'plum', s=10)
plt.scatter(ent_micro10[0],com_micro10[0], label='micro10', c = 'coral')

plt.scatter(ent_micro9,com_micro9, label='Sub-micro9', c = 'plum', s=10)
plt.scatter(ent_micro9[0],com_micro9[0], label='micro9', c = 'coral')

plt.scatter(ent_micro8,com_micro8, label='Sub-micro8', c = 'plum', s=10)
plt.scatter(ent_micro8[0],com_micro8[0], label='micro8', c = 'coral')

plt.scatter(ent_micro7,com_micro7, label='Sub-micro7', c = 'plum', s=10)
plt.scatter(ent_micro7[0],com_micro7[0], label='micro7', c = 'coral')

plt.scatter(ent_micro6,com_micro6, label='Sub-micro6', c = 'plum', s=10)
plt.scatter(ent_micro6[0],com_micro6[0], label='micro6', c = 'coral')

plt.scatter(ent_micro5,com_micro5, label='Sub-micro5', c = 'plum', s=10)
plt.scatter(ent_micro5[0],com_micro5[0], label='micro5', c = 'coral')

plt.scatter(ent_micro4,com_micro4, label='Sub-micro4', c = 'plum', s=10)
plt.scatter(ent_micro4[0],com_micro4[0], label='micro4', c = 'coral')

plt.scatter(ent_micro3,com_micro3, label='Sub-micro3', c = 'plum', s=10)
plt.scatter(ent_micro3[0],com_micro3[0], label='micro3', c = 'coral')

plt.xlabel('Entropía normalizada')
#plt.ylim(0,1)
#plt.xlim(0.4,1)
plt.grid(linewidth=0.1)
#plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
plt.ylabel('Complejidad normalizada')
plt.title('Dispersiones Microscopía')
# Out:
# Text(0.5, 1.0, 'Dispersiones Microscopía')
